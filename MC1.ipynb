# %%
import numpy
import pandas

# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv("cirrhosis.csv")
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df=pd.read_csv("cirrhosis.csv")

# %%
df
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df.shape
# Out:
# (418, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
dff=df.copy()

# %%
pd.set_option('display.max_rows', 100)

# %%
dff.isna()
# Out:
#         ID  N_Days  Status   Drug    Age    Sex  Ascites  Hepatomegaly  \
# 0    False   False   False  False  False  False    False         False
# 1    False   False   False  False  False  False    False         False
# 2    False   False   False  False  False  False    False         False
# 3    False   False   False  False  False  False    False         False
# 4    False   False   False  False  False  False    False         False
# ..     ...     ...     ...    ...    ...    ...      ...           ...
# 413  False   False   False   True  False  False     True          True
# 414  False   False   False   True  False  False     True          True
# 415  False   False   False   True  False  False     True          True
# 416  False   False   False   True  False  False     True          True
# 417  False   False   False   True  False  False     True          True
#
#      Spiders  Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos   SGOT  \
# ...

# %%
dff
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
dff.fillna(0)
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D                0  24472   F       0            0
# 414  415    1103      C                0  14245   F       0            0
# 415  416    1055      C                0  20819   F       0            0
# 416  417     691      C                0  21185   F       0            0
# 417  418     976      C                0  19358   F       0            0
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
dff2= df.copy()

# %%
dff2
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
import warnings

dff.fillna(method='ffill')
# Out:
# C:\Users\anilr\AppData\Local\Temp\ipykernel_28992\3340877433.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dff.fillna(method='ffill')
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D          Placebo  24472   F       N            N
# 414  415    1103      C          Placebo  14245   F       N            N
# 415  416    1055      C          Placebo  20819   F       N            N
# ...

# %%
dff.fillna(0)
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D                0  24472   F       0            0
# 414  415    1103      C                0  14245   F       0            0
# 415  416    1055      C                0  20819   F       0            0
# 416  417     691      C                0  21185   F       0            0
# 417  418     976      C                0  19358   F       0            0
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
dff.fillna(method='ffill')
# Out:
# C:\Users\anilr\AppData\Local\Temp\ipykernel_28992\1776581496.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dff.fillna(method='ffill')
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D          Placebo  24472   F       N            N
# 414  415    1103      C          Placebo  14245   F       N            N
# 415  416    1055      C          Placebo  20819   F       N            N
# ...

# %%
dff.fillna(method='pad', inplace=True)
# Out:
# C:\Users\anilr\AppData\Local\Temp\ipykernel_28992\3779673880.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dff.fillna(method='pad', inplace=True)

# %%
dff.isna().sum()
# Out:
# ID               0
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %%
dff
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D          Placebo  24472   F       N            N
# 414  415    1103      C          Placebo  14245   F       N            N
# 415  416    1055      C          Placebo  20819   F       N            N
# 416  417     691      C          Placebo  21185   F       N            N
# 417  418     976      C          Placebo  19358   F       N            N
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
average_copper = dff['Copper'].mean()
dff1 = dff.fillna({"Copper": average_copper})

# %%
dff1
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D          Placebo  24472   F       N            N
# 414  415    1103      C          Placebo  14245   F       N            N
# 415  416    1055      C          Placebo  20819   F       N            N
# 416  417     691      C          Placebo  21185   F       N            N
# 417  418     976      C          Placebo  19358   F       N            N
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
import numpy as np
dff3 =dff2.replace(np.NaN, 50)
dff3
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D               50  24472   F      50           50
# 414  415    1103      C               50  14245   F      50           50
# 415  416    1055      C               50  20819   F      50           50
# 416  417     691      C               50  21185   F      50           50
# 417  418     976      C               50  19358   F      50           50
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df1=df.copy()

# %%
df1
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df1.replace(np.NaN, 1)
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D                1  24472   F       1            1
# 414  415    1103      C                1  14245   F       1            1
# 415  416    1055      C                1  20819   F       1            1
# 416  417     691      C                1  21185   F       1            1
# 417  418     976      C                1  19358   F       1            1
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
import numpy as np

# Replace NaN (missing values) in the 'Copper' column with 1.1
df1['Copper'] = df1['Copper'].replace(np.NaN, 1.1)
df1
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df1['Copper'].replace(np.NaN, 1.1)
# Out:
# 0      156.0
# 1       54.0
# 2      210.0
# 3       64.0
# 4      143.0
#        ...
# 413      1.1
# 414      1.1
# 415      1.1
# 416      1.1
# 417      1.1
# Name: Copper, Length: 418, dtype: float64

# %%
df1['SGOT_values'].fillna(10)
# Out:
# 0      137.95
# 1      113.52
# 2       96.10
# 3       60.63
# 4      113.15
#         ...
# 413     10.00
# 414     10.00
# 415     10.00
# 416     10.00
# 417     10.00
# Name: SGOT_values, Length: 418, dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')
df1['SGOT_values'].replace(10, 45, inplace=True)

# %%
df1['Drug_Name]= df1['Drug'].str.extract()
# Out:
#   Cell In[345], line 1
#     df1['Drug_Name]= df1['Drug'].extract(Name)
#                               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df1
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
# To reset the index of the DataFrame
dff3 = dff3.reset_index(drop=True)

# %%
dff3
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D               50  24472   F      50           50
# 414  415    1103      C               50  14245   F      50           50
# 415  416    1055      C               50  20819   F      50           50
# 416  417     691      C               50  21185   F      50           50
# 417  418     976      C               50  19358   F      50           50
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
# Reset the index but retain the old index as a new column
dff3 = dff3.reset_index(drop=False)

# %%
dff3
# Out:
#      index   ID  N_Days Status             Drug    Age Sex Ascites  \
# 0        0    1     400      D  D-penicillamine  21464   F       Y
# 1        1    2    4500      C  D-penicillamine  20617   F       N
# 2        2    3    1012      D  D-penicillamine  25594   M       N
# 3        3    4    1925      D  D-penicillamine  19994   F       N
# 4        4    5    1504     CL          Placebo  13918   F       N
# ..     ...  ...     ...    ...              ...    ...  ..     ...
# 413    413  414     681      D               50  24472   F      50
# 414    414  415    1103      C               50  14245   F      50
# 415    415  416    1055      C               50  20819   F      50
# 416    416  417     691      C               50  21185   F      50
# 417    417  418     976      C               50  19358   F      50
#
#     Hepatomegaly Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  \
# 0              Y       Y     Y       14.5        261.0     2.60   156.0
# ...

# %%
dff1
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D          Placebo  24472   F       N            N
# 414  415    1103      C          Placebo  14245   F       N            N
# 415  416    1055      C          Placebo  20819   F       N            N
# 416  417     691      C          Placebo  21185   F       N            N
# 417  418     976      C          Placebo  19358   F       N            N
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
dff1['Drugs']=dff1['Drug'].str.split('-', expand=True)

# %%
dff1
# Out:
#            0              1
# 0          D  penicillamine
# 1          D  penicillamine
# 2          D  penicillamine
# 3          D  penicillamine
# 4    Placebo           None
# ..       ...            ...
# 413  Placebo           None
# 414  Placebo           None
# 415  Placebo           None
# 416  Placebo           None
# 417  Placebo           None
#
# [418 rows x 2 columns]

# %%
df2=df.copy()

# %%
df2
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df2.replace(np.NaN, 500)
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              500  24472   F     500          500
# 414  415    1103      C              500  14245   F     500          500
# 415  416    1055      C              500  20819   F     500          500
# 416  417     691      C              500  21185   F     500          500
# 417  418     976      C              500  19358   F     500          500
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
#df2['Cholesterol']>490.0
df2[df2['Cholesterol'] > 490.0]
# Out:
# Empty DataFrame
# Columns: [ID, N_Days, Status, Drug, Age, Sex, Ascites, Hepatomegaly, Spiders, Edema, Bilirubin, Cholesterol, Albumin, Copper, Alk_Phos, SGOT, Tryglicerides, Platelets, Prothrombin, Stage, SGOT_values]
# Index: []

# %%
#df2[df2['Cholesterol'] > 490.0]
df2.loc[df2['Cholesterol'] > 490.0, 'Cholesterol'] = 380
df2
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df2['Cholesterol'].dtype
# Out:
# dtype('float64')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#average_copper = dff['Copper'].mean()
#dff1 = dff.fillna({"Copper": average_copper})
# Replace NaN values in the DataFrame with the mean of their respective columns
#df2.fillna(df2.mean(), inplace=True)
# Replace NaN values only in numeric columns with the mean of those columns
df2.fillna(df2.select_dtypes(include='number').mean(), inplace=True)

# %%
df2
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin      Copper     Alk_Phos  \
# ...

# %%
# Replace NaN in object columns with the mode (most frequent value) of each column
df2.fillna(df2.select_dtypes(include='object').mode().iloc[0], inplace=True)

# %%
df2
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D  D-penicillamine  24472   F       N            Y
# 414  415    1103      C  D-penicillamine  14245   F       N            Y
# 415  416    1055      C  D-penicillamine  20819   F       N            Y
# 416  417     691      C  D-penicillamine  21185   F       N            Y
# 417  418     976      C  D-penicillamine  19358   F       N            Y
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin      Copper     Alk_Phos  \
# ...

# %%
df2.shape
# Out:
# (418, 21)

# %%
#sns.heatmap(df2.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.figure(figsize=(10, 8))
sns.heatmap(df2.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
#df2(sns.boxplot('Bilirubin','Cholesterol','Albumin'))
Variables= ['Bilirubin','Cholesterol','Albumin']
df2[Variables].boxplot()
plt.show()

# %%
sns.boxplot(y='Bilirubin', data=df2)
#df2.boxplot(column='Bilirubin')
plt.show()

# %%
#sns.scatterplot(y='Cholesterol', data=df2)
sns.scatterplot(x='Bilirubin', y='Cholesterol', data=df2, hue='Bilirubin')
plt.show()

# %%
Q1= df2.Bilirubin.quantile(0.25)
Q3= df2.Bilirubin.quantile(0.75)
Q1,Q3
# Out:
# (0.8, 3.4)

# %%
IQR=Q3-Q1
IQR
# Out:
# 2.5999999999999996

# %%
lower_limit= Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (-3.0999999999999996, 7.299999999999999)

# %%
"""
df2= sorted(da)
Q1=np.quantile(df2,25)
Q3=np.quantile(df2,75)
IQR= Q3-Q1
lower_limit= Q1-1.5*IQR
upper_limit= Q3+1.5*IQR
"""
# Out:
# '\ndf2= sorted(da)\nQ1=np.quantile(df2,25)\nQ3=np.quantile(df2,75)\nIQR= Q3-Q1\nlower_limit= Q1-1.5*IQR\nupper_limit= Q3+1.5*IQR\n'

# %%
"""
numeric_columns = df2.select_dtypes(include='number').columns
for column in numeric_columns:
    data = df2[column]
    
    Q1 = np.quantile(data, 0.25)
    Q3 = np.quantile(data, 0.75)
    
   
    IQR = Q3 - Q1
    
   
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    
   
    outliers = data[(data < lower_limit) | (data > upper_limit)]
"""
# Out:
# "\nnumeric_columns = df2.select_dtypes(include='number').columns\nfor column in numeric_columns:\n    data = df2[column]\n    \n    Q1 = np.quantile(data, 0.25)\n    Q3 = np.quantile(data, 0.75)\n    \n   \n    IQR = Q3 - Q1\n    \n   \n    lower_limit = Q1 - 1.5 * IQR\n    upper_limit = Q3 + 1.5 * IQR\n    \n   \n    outliers = data[(data < lower_limit) | (data > upper_limit)]\n"

# %%
"""
max_thresold= df2['Bilirubin'].quantile(0.95)
max_thresold

df2[df2['Bilirubin']>max_thresold]


min_thresold= df2['Bilirubin'].quantile(0.05)
min_thresold

df2[df2['Bilirubin']< min_thresold]

max_thresold,min_thresold= df2.new_column.quantile([0.95,0.25])
"""
# Out:
# "\nmax_thresold= df2['Bilirubin'].quantile(0.95)\nmax_thresold\n\ndf2[df2['Bilirubin']>max_thresold]\n\n\nmin_thresold= df2['Bilirubin'].quantile(0.05)\nmin_thresold\n\ndf2[df2['Bilirubin']< min_thresold]\n\nmax_thresold,min_thresold= df2.new_column.quantile([0.95,0.25])\n"
